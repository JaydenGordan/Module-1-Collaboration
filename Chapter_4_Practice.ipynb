# %%
song = """When an eel grabs your arm,
And it causes great harm,
That's - a moray!"""

song = song.replace("moray", "Moray")
print(song)
# Out:
# When an eel grabs your arm,
# And it causes great harm,
# That's - a Moray!

# %%
food1 = "roast beef"
food2 = "ham"
body_part = "head"
animal = "clam"

print(f"""My kitty cat likes {food1},
My kitty cat likes {food2},
My kitty cat fell on his {body_part}
And now thinks he's a {animal}.""")
# Out:
# My kitty cat likes roast beef,
# My kitty cat likes ham,
# My kitty cat fell on his head
# And now thinks he's a clam.

# %%
letter = """Dear {salutation} {name},

Thank you for your letter. We are sorry that our {product}
{verbed} in your {room}. Please note that it should never
be used in a {room}, especially near any {animals}.

Send us your receipt and {amount} for shipping and handling.
We will send you another {product} that, in our tests,
is {percent}% less likely to have {verbed}.

Thank you for your support.

Sincerely,
{spokesman}
{job_title}"""

salutation = "Mr."
name = "Smith"
product = "vacuum cleaner"
verbed = "exploded"
room = "bathroom"
animals = "cats"
percent = 50
spokesman = "John"
job_title = "Customer Service Manager"
amount = "$20"

print(letter.format(
    salutation=salutation,
    name=name,
    product=product,
    verbed=verbed,
    room=room,
    animals=animals,
    amount=amount,
    percent=percent,
    spokesman=spokesman,
    job_title=job_title
))
# Out:
# Dear Mr. Smith,
#
# Thank you for your letter. We are sorry that our vacuum cleaner
# exploded in your bathroom. Please note that it should never
# be used in a bathroom, especially near any cats.
#
# Send us your receipt and $20 for shipping and handling.
# We will send you another vacuum cleaner that, in our tests,
# is 50% less likely to have exploded.
#
# Thank you for your support.
#
# Sincerely,
# John
# Customer Service Manager

# %%
duck = "Ducky McDuckface"
gourd = "Gourdy McGourdface"
spitz = "Spitzy McSpitzface"

print(f"{duck}, {gourd}, and {spitz}")
# Out:
# Ducky McDuckface, Gourdy McGourdface, and Spitzy McSpitzface
